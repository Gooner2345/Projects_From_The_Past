# %%
# Dialouge between host and contestant

#---- Develop: Thabo Gcabashe

"""#Doc string :
#Greetings everybody and welcome to the Fantasy Premier League lottery pick. Every year 
#the top 5 overall placed participants from the previous season are allowed to draw 
#one of the top 5 performing player. This year we have decided to add more activities 
#before and after the lottery pick for more fun. 
     
#Directions
     
#Round_1: coin toss - Guess heads or tails and the will tell you if you correct
#Round_2: Lottery pick - Select a number between 0 - 4 and see which player you picked
#Round_3: Guess the footballer and win a prize. Lots of fun for everyone
     
#Bug: in round_2 when you select any letter or number other than 0,1,2,3,4 it recgonizes the answer as correct even when it is not."""



 

import sys
from random import randint
from colorama import Fore,Back

        
        
        
        
    
def game_start ():
    global contestant_name
    global favourite_team
    global favourite_player
    global Support_team 
    global round_1
    global round_2
    global round_3 

import time
import random







print(f""" 

Welcome Ladies & Gentlemen to the 2020 Fantasy premier league lottery draft!!.

""") 

contestant_name = input( prompt = """ Before we get started please insert name\t""")

time.sleep(1)

            



# From the questions answered we will make a intro for consteatant

time.sleep(1)

     
     
     
# After the directions play heads or tails for hints further on in the game.
 

time.sleep(1)
    
print(f""" \nBefore we get started with the fantasy pick there is a special
\nhint which will help in round 3. {contestant_name} will decide if he wants to flip a coin
\nto see if they recieve the hint.""")



input(prompt = '< Press any key to continue>\n') 
 
       
 # When users flips a comparison betwen the input and number are made to see if guessed correct

flip = True

while flip == True:  
    number = random.randint(1,2)
    guess = input("Heads or Tails: ")
    
    #Heads is thrown and guessed
    
    if number == 1 and guess == "Heads":
        print("It's your lucky day, the hint is he won his first Fifa World Cup as a teenager in 2018 ")
        time.sleep(1)
        throw = input("Do you wish to throw again, yes/no: ") 
        
    #Tails is thrown and guessed 
    
    elif number == 2 and guess == "Tails":
        print("oh yes lucky you, the hint is he won hit first Fifa World Cup as a teenager in 2018 ")
        time.sleep(1)
        throw = input(" Do you wish to throw again, yes/no: ")
        
    #Heads is thrown and tails is guessed 
    
    elif number == 2 and guess == "Tails": 
        print("You guessed wrong sorry ")
        time.sleep(1)
        throw = input(" Do you wish to throw again, yes/no: ")
        
        time.sleep(1)
        
    #Tails is thrown and heads is guessed
    
    elif number == 2 and guess == "Heads":
        print("You guessed wrong sorry ")
        time.sleep(1)
        throw = input(" Do you wish to throw again yes/no: ")
          
        time.sleep(1)
        
    #If neither Heads or tails guessed
    
    
    else:
        print("You've entered wrong, make sure your answer starts with a capital letter")
        time.sleep(1)
        throw = input(" Do you wish to throw again, yes/no: ")
        
    if throw == "yes":
        flip = True
    elif throw == "no":
        flip = False 
        
        time.sleep(1)
        
input( prompt = '< Press any key to continue to next round>\n')


print(f""" Welcome back {contestant_name} I hope you remembered the hint it will come
in handy for the final round.




In this round you will select from a set of the top 5 players from the fantasy league
scores. Your selection will be at random so you will only have one chance to pick a player.

Before we get started the audience want to know.""")

favourite_player = input(prompt = """

 Who is your favourite player that is currently playing ?  """)


input( prompt ='< Press any key to continue to next round>\n')

     



print("We shall ask you to select a number between 0-4 then based on that number you will recieve a player") 



# From the user number range I let users select a number from the range then each number would has a print() which produces with player name

     



user_number_from_range = int(input( "Please enter a number from the range: ")) 


                    
                    

if user_number_from_range < 0 or user_number_from_range > 4: 
    print("Please enter a number in the range of 0 - 4")
     
          
     
     
    
else: 
    if user_number_from_range == 0:
        print(" You have selected Kevin De Bruyne")
        
# When user inputs the number 1 the resulting print() is Mohamed Salah        
    else:
        if user_number_from_range == 1:
            print(" You have selected Mohamed Salah")
#When user inputs the number 1 the resulting print() is Sadio Mane            
        else:
            if user_number_from_range == 2:
                print(" You have selected Sadio Mane")
#When user inputs the number 1 the resulting print() is Pierre-Emerick Aubameyang                
            else: 
                if user_number_from_range == 3:
                    print(" You have selected Pierre-Emerick Aubameyang")
#When user inputs the number 1 the resulting print() is Raheem Sterling                    
                else:
                    if user_number_from_range == 4:
                        print(" You have selected Raheem Sterling")
                        
               
        
time.sleep(1) 


                        
print(f""" Alright {contestant_name} it is time to move to the final round but before we get there 
we want to ask another questoin. """)

favourite_team = input(prompt = "Which English premier league team is your favourite? ")
 
    
input(prompt = '< Press any key to continue to next round>\n')


print("In this final round we shall give you 3 chances to guess the player.If you guess correctly, you shall win a free ticket to a game of your choice")

#Guess the name by creating a secret word then giving the user 3 chances to guess it.


 

secret_word = "Kylian Mbappe"  
guess = ""
guess_count = 0
guess_limit = 3
out_of_guesses = False

#Guess the secret word or try again

while guess != secret_word and not(out_of_guesses):
    
    if guess_count < guess_limit: 
        guess = input("Enter guess: ")
        guess_count += 1
        
    else:
        out_of_guesses = True 
        
if out_of_guesses:
    print("Out of guesses, the correct guess is Kylian Mbappe")
    print(Fore.BLUE+'-'*75)
    print(Fore.RESET)
    
else:
    print(f""" You win!! Congradulations. Seeing as you answered the correctly we'll award you with a ticket to watch {favourite_team} and 
    we shall be giving you a signed shirt from {favourite_player} """) 
    print(Fore.BLUE+'-'*75)
    print(Fore.RESET)
print(f""" Thank you ladies and gentleman for joining us tonight, {contestant_name} has been a lovely contestant and we
hope he enjoys his prizes. Thank you again everyone and have a good night""")
# Out:
#
#
# Welcome Ladies & Gentlemen to the 2020 Fantasy premier league lottery draft!!.
#
#
#  Before we get started please insert name	sv
#
# Before we get started with the fantasy pick there is a special
#
# hint which will help in round 3. sv will decide if he wants to flip a coin
#
# to see if they recieve the hint.
# < Press any key to continue>
# a
# Heads or Tails: heads
# You've entered wrong, make sure your answer starts with a capital letter
#  Do you wish to throw again, yes/no: no
# < Press any key to continue to next round>
# g
#  Welcome back sv I hope you remembered the hint it will come
# in handy for the final round.
#
#
#
#
# In this round you will select from a set of the top 5 players from the fantasy league
# scores. Your selection will be at random so you will only have one chance to pick a player.
#
# Before we get started the audience want to know.
#
#
#  Who is your favourite player that is currently playing ?  bernardo silva
# ...
